# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload
# %autoreload 2

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/Users/Molly/miniconda3/envs/b1sc_cenv/lib/python311.zip', '/Users/Molly/miniconda3/envs/b1sc_cenv/lib/python3.11', '/Users/Molly/miniconda3/envs/b1sc_cenv/lib/python3.11/lib-dynload', '', '/Users/Molly/miniconda3/envs/b1sc_cenv/lib/python3.11/site-packages', '/Users/Molly/Documents/Oxford 24-25/B1/b1-coding-practical-mt24']

# %%
# making sure data was read correctly
from uuv_mission.dynamic import Mission

mission_instance = Mission.from_csv("../data/mission.csv")

print("Ref", mission_instance.reference)
print("Height", mission_instance.cave_height)
print("depth", mission_instance.cave_depth)
# Out:
# Ref [ 0.          2.9239131   5.51432416  7.48758532  8.65202856  8.9358434
#   8.39641558  7.20973438  5.64159015  4.00512537  2.61142659  1.72091746
#   1.5031691   2.01140425  3.17564866  4.81554192  6.67072159  8.44392729
#   9.84996868 10.66277828 10.75307162 10.11061551  8.84752915  7.18203021
#   5.40512093  3.83540296  2.76909013  2.43306084  2.94833378  4.30973288
#   6.38498424  8.93345286 11.64165764 14.17007897 16.20400695 17.50054627
#  17.92449464 17.46755263 16.24792901 14.49047024 12.49048405 10.56696897
#   9.01260615  8.04835863  7.78978173  8.23029238  9.24396757 10.6073632
#  12.03684862 13.23550874 13.94215995 13.97469282 13.26084805 11.85151023
#   9.91435723  7.70879856  5.54608736  3.74083483  2.56152303  2.1877885
#   2.68120511  3.97419381  5.87885843  8.11443358 10.34912038 12.24983594
#  13.53216395 14.00276265 13.5876664  12.34212299 10.44049644  8.14787894
#   5.7779107   3.64345268  2.00786033  1.04449325  0.81078468  1.24089274
# ...

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission.dynamic import Submarine, Controller, ClosedLoop, Mission
sub = Submarine()
# Instantiate your controller (depending on your implementation)
Kd = 0.6
Kp = 0.15
my_controller = Controller(Kd, Kp)
closed_loop = ClosedLoop(sub, my_controller)
mission = Mission.from_csv("../data/mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)

# %%
#testing with other cave terrains
# Import relevant modules
from uuv_mission.dynamic import Submarine, Controller, ClosedLoop, Mission
sub = Submarine()
# Instantiate your controller (depending on your implementation)
Kd = 0.6
Kp = 0.15
my_controller = Controller(Kd, Kp)
closed_loop = ClosedLoop(sub, my_controller)
mission = Mission.random_mission(100, 10)

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
